# %% [markdown]
# # Information Retrieval Project
# ## COVID-19 Search Engine (P12)
#
# Content-based image retrieval (CBIR) is a computer vision technique which addresses the problem of searching for digital images in large databases. A content-based approach exploits the contents of an image, such as colors, shapes and textures, differing from its concept-based counterpart, which instead focuses on keywords and tags associated with the image itself.
#
# Image retrieval has gained more and more relevance in the medical field, due to the accumulation of extensive collections of scans in hospitals. These images are stored in DICOM format, which must be manually annotated and may require considerable time to process by physicians. The goal of this project is trying to address this problem by considering different approaches for building a content-based medical image retrieval system and comparing their results based on classification metrics and computational time.

# %% [markdown]
# # Installation of Requirements
#
# This part of the code installs necessary dependencies specified in the `requirements.txt` file.
# Utilizes the `!pip install -r requirements.txt` command to install packages listed in the `requirements.txt` file. This ensures that all required dependencies are installed before proceeding with execution.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: kaggle==1.6.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.6.6)
# Requirement already satisfied: Pillow==10.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (10.2.0)
# Requirement already satisfied: matplotlib==3.8.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (3.8.3)
# Requirement already satisfied: pandas==2.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: numpy==1.26.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: keras==3.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.1.1)
# Requirement already satisfied: tensorflow==2.16.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2.16.1)
# Requirement already satisfied: scikit-learn==1.4.1.post1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.4.1.post1)
# Requirement already satisfied: seaborn==0.13.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.13.2)
# Requirement already satisfied: six>=1.10 in /Users/matteo/Library/Python/3.10/lib/python/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: python-dateutil in /Users/matteo/Library/Python/3.10/lib/python/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (4.66.1)
# Requirement already satisfied: python-slugify in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (8.0.3)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (1.26.12)
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kaggle==1.6.6->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 4)) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/matteo/Library/Python/3.10/lib/python/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas==2.2.1->-r requirements.txt (line 5)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas==2.2.1->-r requirements.txt (line 5)) (2023.3)
# Requirement already satisfied: absl-py in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras==3.1.1->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras==3.1.1->-r requirements.txt (line 7)) (13.7.1)
# Requirement already satisfied: namex in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras==3.1.1->-r requirements.txt (line 7)) (0.0.7)
# Requirement already satisfied: h5py in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras==3.1.1->-r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: optree in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras==3.1.1->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: ml-dtypes in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras==3.1.1->-r requirements.txt (line 7)) (0.3.2)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (4.23.4)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (58.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (1.60.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (2.16.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.1->-r requirements.txt (line 8)) (0.36.0)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn==1.4.1.post1->-r requirements.txt (line 9)) (1.11.3)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn==1.4.1.post1->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn==1.4.1.post1->-r requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.16.1->-r requirements.txt (line 8)) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->kaggle==1.6.6->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->kaggle==1.6.6->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->-r requirements.txt (line 8)) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->-r requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->-r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bleach->kaggle==1.6.6->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-slugify->kaggle==1.6.6->-r requirements.txt (line 2)) (1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich->keras==3.1.1->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/matteo/Library/Python/3.10/lib/python/site-packages (from rich->keras==3.1.1->-r requirements.txt (line 7)) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras==3.1.1->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.1->-r requirements.txt (line 8)) (2.1.3)

# %% [markdown]
# # Importing Required Libraries
#
# This part of the code imports necessary libraries.

# %%
# Import
import os
import time
import glob
import kaggle

import keras
import numpy as np
import pandas as pd
import matplotlib.image as mpimg

from keras.models import Model
from keras.utils import load_img, img_to_array
from keras.applications.vgg16 import VGG16, preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances, manhattan_distances

from matplotlib import pyplot as plt
from PIL import Image, UnidentifiedImageError

# %% [markdown]
# # Definition of constants
#
# This part of the code defines useful constants and paths.

# %%
# ************************************** #
# ************** CONSTANTS ************* #
# ************************************** #

# PATHS
PROJECT_ROOT = os.getcwd()  # The project root
DATASET_PATH = "archives"  # Path to the dataset
DATASET_ID = "plameneduardo/sarscov2-ctscan-dataset"  # ID for Kaggle API. Format: dataset_owner_name/dataset_name
COVID_PATH = os.path.join(DATASET_PATH, "COVID")  # Path to data labeled as COVID
NON_COVID_PATH = os.path.join(DATASET_PATH, "non-COVID")  # Path to data labeled as non-COVID
DATA_PATH = "data"  # Path to the data folder 
PLOT_PATH = "plot"  # Path to the plot folder
TRAIN_DATA_PATH = os.path.join(DATA_PATH, "train_data.csv")  # Path to train data
TEST_DATA_PATH = os.path.join(DATA_PATH, "test_data.csv")  # Path to test data
VGG16_FEATURES_PATH = os.path.join(DATA_PATH, "VGG16_extracted_feature.json")  # Path to VGG16 extracted features
RESNET50_FEATURES_PATH = os.path.join(DATA_PATH, "ResNet50_extracted_feature.json")  # Path to ResNet50 extracted features
MOBILENET_FEATURES_PATH = os.path.join(DATA_PATH, "MobileNet_extracted_feature.json") # Path to MobileNet extracted features


# DATA, KERAS AND SIMILAR
CLASSES = ["COVID", "non-COVID"]
IMG_WIDTH = 224
IMG_HEIGHT = 224
IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)
CHANNELS = 3
BATCH_SIZE = 32
INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

# DISTANCE FUNCTIONS
EUCLIDEAN = "Euclidean"
COSINE = "Cosine"
MANHATTAN = "Manhattan"

# Define a dictionary to map distance metric names to their ranges
DISTANCE_RANGES = {
    COSINE: "[0, 2]",
    EUCLIDEAN: "[0, inf)",
    MANHATTAN: "[0, inf)"
}

# %% [markdown]
# # Building the Workspace
#
# Definition of useful directory and executing the dataset Download.
#
# ## Download dataset from Kaggle
#
# If the dataset does not exist, the code proceeds to download it from Kaggle using the `kaggle.api.dataset_download_files()` function.

# %%
# Create a directory
def makedir(dir_path: str) -> None:
    """
    Create a directory, given a path

    :param dir_path: directory location
    
    :return: None
    """
    # check if dir exists
    if not os.path.exists(dir_path):
        os.makedirs(dir_path, exist_ok=True)
        print("\n> Directory [{}] has been created successfully!".format(dir_path))
        
        
# Download dataset from Kaggle website
def download_dataset_from_kaggle(dataset_id: str, dataset_path: str) -> None:
    """
    Download the sarscov2-ctscan-dataset using Kaggle module

    :param dataset_id: identify the dataset to download.
        Format: dataset_owner_name/dataset_name
    :param dataset_path: location to save the dataset

    :return: None
    """
    # Download the dataset if not exist in the workplace
    if not os.path.exists(path=dataset_path):
        
        print("\n> Download the dataset from Kaggle...")
        # Download dataset and unzip it
        kaggle.api.dataset_download_files(dataset=dataset_id, path=dataset_path, quiet=False, unzip=True)
    else:
        print("\n> Dataset already downloaded.")


## ************************************ DEFINING THE WORKSPACE ********************************** ##      

# Execute the download operation
download_dataset_from_kaggle(dataset_id=DATASET_ID, dataset_path=DATASET_PATH)

# Create data folder
makedir(DATA_PATH)

# Create plot folder
makedir(PLOT_PATH)
# Out:
# > Dataset already downloaded.

# %% [markdown]
# # Dataset Preprocessing Summary
#
# This code performs preprocessing tasks on a dataset, which includes counting files, checking for corrupted files, and plotting duplicate images alongside their originals.
#
# ## 1. Counting Files
# The `count_files` function counts the number of files with specified extensions in a specified directory. It takes the directory path and file extensions as inputs and returns the count of files.
#
# ## 2. Checking for Corrupted Files
# The `corruption_filter` function checks the dataset for corrupted image files and provides an option to delete them. It iterates through all files, verifies their integrity using PIL's `Image` module, and removes corrupted files if requested.
#
# ## Usage
# 1. The code begins with checking the dataset's file count before preprocessing tasks.
# 2. It then checks for corrupted files and provides an option to delete them.
# 3. Finally, it confirms the total file count after preprocessing.
#
# This code ensures the integrity and cleanliness of the dataset for further analysis or model training.

# %%
# Count the number of files
def count_files(directory_path: str, extensions="png") -> int:
    """
    Count the number of files with specified extensions in the specified directory.

    Example: count_files("/path/to/directory", extensions=["jpg", "png"]) -> 12

    :param directory_path: (str) The path to the directory for which file count is required.
    :param extensions: (list or None) List of file extensions to count. If None, count all files.

    :return: (int) The number of files with specified extensions in the specified directory.
    """
    if extensions is None:
        # If no extensions provided, consider all files
        extensions = ['']
    
    # Initialize counter for files
    counter = 0 
    # Iterate over the directory
    with os.scandir(directory_path) as entries:
        for entry in entries:
             # Check if it's a file with specified extension
            if entry.is_file() and any(entry.name.lower().endswith(ext) for ext in extensions):
                counter += 1

    return counter


# Just a helper function
def print_file_counts() -> None:
    """
    A helper function that print information about the number of files inside the directory.
    
    :return: None
    """
    count_covid = count_files(directory_path=COVID_PATH)  # Count COVID files
    count_non_covid = count_files(directory_path=NON_COVID_PATH)  # Count non-COVID files
    
    # Total number of files
    tot_number_file = count_covid + count_non_covid
    # Print the counts
    print("- Total Number of file: {}\n".format(tot_number_file) +
          "- Number of file in COVID: {}\n".format(count_covid) +
          "- Number of file in non-Covid: {}\n".format(count_non_covid))
    

# Check dataset: filter out possible corrupted files.
def corruption_filter(dataset_path: str) -> None:
    """
    Check dataset for corrupted files and delete them if requested.

    :param dataset_path: The path to the dataset.
    
    :return: None
    """
    # Find all image files in the dataset
    image_files = glob.glob(os.path.join(dataset_path, "**", "*.jpg"), recursive=True)
    
    bad_files = []  # to store corrupted file
    
    # Loop 
    for image_file in image_files:
        try:
            with Image.open(image_file) as img:
                img.verify()
        except UnidentifiedImageError:
            bad_files.append(image_file)
            print("\n> There are {} corrupted files: {}".format(len(bad_files), bad_files))

    if len(bad_files) != 0:  # If there are corrupted files -> Delete them
        doc_message = input("\n> Do you want to delete these {} file? [Y/N]: ".format(len(bad_files)))
        if doc_message.upper() == "Y":
            for bad_file in bad_files:
                # Delete corrupted file
                os.remove(bad_file)
                # Print success message
                print("- {} Corrupted File Deleted Successfully!".format(bad_file))

            # Update file counts after removal of corrupted files
            print("\n> Checking the Number of file after the application of the corruption filter:")
            print_file_counts()
    else:  # If no corrupted files found
        print("> No Corrupted File Found")


# Pre-Processing Workflow
def checking_dataset(dataset_path: str) -> None:
    """
    Preliminary check on dataset:
        Calling corruption_filter, find_out_duplicate to analyze and control the dataset.
 
    :param dataset_path: The path to the dataset.
    
    :return: None
    """
    print("\n> CHECK THE DATASET")
    print("\n> Checking the Number of file before performing Pre-processing Task...")
    
    # Print count
    print_file_counts()
    
    # Check for corrupted file
    print("> Checking for corrupted files...")
    corruption_filter(dataset_path=dataset_path)
    
    print("\n> Final check to confirm the total file count:")
    print_file_counts()
    
    print("> DATASET CHECK COMPLETE!")


## ************************************ CHECKING THE DATASET ********************************** ##


# Execute Pre-Processing tasks on dataset 
checking_dataset(dataset_path=DATASET_PATH)
# Out:
# > CHECK THE DATASET
#
# > Checking the Number of file before performing Pre-processing Task...
# - Total Number of file: 2481
# - Number of file in COVID: 1252
# - Number of file in non-Covid: 1229
#
# > Checking for corrupted files...
# > No Corrupted File Found
#
# > Final check to confirm the total file count:
# - Total Number of file: 2481
# - Number of file in COVID: 1252
# - Number of file in non-Covid: 1229
#
# > DATASET CHECK COMPLETE!

# %% [markdown]
# # Data Preparation

# %%
# Define a pandas dataframe
def build_dataframe(dataset_path: str) -> pd.DataFrame:
    """
    Build a dataframe from dataset
    
    :param dataset_path: Path to the dataset
    
    :return: dataframe
         - File path: path to images.
         - ID: binary label for the two classes (0, 1).
         - Class Label: string label for the two classes (COVID, non-COVID).
    """
    data = []
    
    for class_id, class_label in enumerate(CLASSES):
        # Folder path -> archives/COVID or archives/non-COVID
        path_to_class_folder = os.path.join(dataset_path, class_label)  
        
        for file in os.listdir(path_to_class_folder):
            # File path -> example. archives/COVID/Covid (1).png
            path_to_file = os.path.join(path_to_class_folder, file)
            
            # Append file information along with class label to the data list
            data.append([path_to_file, class_id, class_label])
            
    # Create a DataFrame using the collected data with appropriate column name
    data_df = pd.DataFrame(data=data, columns=["file_path", "id", "class_label"])
    
    return data_df


# Plot the distribution of classes
def plot_class_distribution(data: pd.DataFrame) -> None:
    """
    Plot bar graph showing the distribution of classes.
    
    :param data: pd.Dataframe contain data.
    
    :return: None.
    """
    class_count = [0, 0]  # binary classes
    colors = ["skyblue", "orange"]  # Assigning colors to classes
        
    # Counting 
    for label in data.iloc[:, 1]:
        class_count[label] += 1
    
    # Plot bar-graph      
    bars = plt.bar(CLASSES, class_count, color=colors)
    plt.xlabel("Class", fontsize=14)
    plt.ylabel("Count", fontsize=14)
    plt.title("Class Distribution", fontsize=14)
    
    # Adding labels on top of the bars
    for bar, count in zip(bars, class_count):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count,
                 ha="center", va="bottom", fontsize=10)
    
    # Save the plot to path
    plot_path = os.path.join(PLOT_PATH, "class_distribution_plot.jpg") 
    plt.savefig(plot_path, dpi=96)

    # Display the plot
    plt.show()

## ************************************ BUILD THE DATASET DATAFRAME ********************************** ##

# Build the dataframe 
dataset_df = build_dataframe(dataset_path=DATASET_PATH)

# Display the dataframe
dataset_df.head()
# Out:
#                         file_path  id class_label
# 0  archives/COVID/Covid (640).png   0       COVID
# 1  archives/COVID/Covid (210).png   0       COVID
# 2  archives/COVID/Covid (705).png   0       COVID
# 3  archives/COVID/Covid (355).png   0       COVID
# 4  archives/COVID/Covid (586).png   0       COVID

# %%
plot_class_distribution(data=dataset_df)

# %%
# Splitting dataset into Training and Test
training_df, test_df = train_test_split(dataset_df, test_size=4, shuffle=True, random_state=4)

# Save dataframe as CSV file format
csv_train_path = os.path.join(DATA_PATH, "train_data.csv")  # Training set
training_df.to_csv(path_or_buf=csv_train_path, index=False)

csv_test_path = os.path.join(DATA_PATH, "test_data.csv")  # Test set
test_df.sort_values(by=["id"], ascending=True, inplace=True)
test_df.to_csv(path_or_buf=csv_test_path, index=False)

# Read the data from the specified path 
train_data = pd.read_csv(filepath_or_buffer=TRAIN_DATA_PATH)
test_data = pd.read_csv(filepath_or_buffer=TEST_DATA_PATH)

# %% [markdown]
# # VGG16
#
# Building VGG16 model class for features extraction.
#
# ## 1. Class Structure
# The `VGG16Net` class encapsulates functionality for feature extraction using the VGG16 model. It includes attributes for the input shape, the model itself, and the output layer.
#
# ## 2. Initialization
# The `__init__` method initializes the `VGG16Net` object. It loads the VGG16 model with pre-trained weights, sets a custom name for the model, and retrieves the output layer.
#
# ## 3. Preprocessing and Loading Images
# The `loading_images` method preprocesses and loads an image from the specified path. It resizes the image to match the input shape of the model, converts it to a NumPy array, adds an extra dimension for batching, and preprocesses the image according to the model's requirements.
#
# This class provides a convenient interface for extracting features from images using the VGG16 model.

# %%
class VGG16Model:
    """
    A class for extracting features from images using the VGG16 model.
    
    Attributes:
        input_shape (tuple): The shape of the input images expected by the model.
        model (keras.Model): The VGG16 model with the fully connected layers removed.
        output (keras.layers.Layer): The output layer of the model.
    """
    def __init__(self):
        """
        Initializes the VGG16Net object.
        """
        self.input_shape = INPUT_SHAPE  # Input shape
        self.model = VGG16(weights="imagenet", input_shape=self.input_shape, include_top=True)  # Load VGG16 model with pre-trained weights
        self.model_name = "VGG16"  # Custom name for the model
        self.model.name = self.model_name  # Set custom name for the model
        self.output = self.model.get_layer("fc2").output  # Get output layer of the model
        self.model = Model(self.model.input, self.output, name=self.model_name) # Create a new model with input as VGG16 input and output as fc2 output


    # Preprocessing and Loading 
    def loading_images(self, path_to_data: str) -> np.ndarray:
        """
        Preprocesses and loads an image from the specified path.

        :param path_to_data: The path to the image file.
 
        :return numpy.ndarray: The preprocessed image as a numpy array.
        """
        # Load the image and resize it to match the input shape of the model
        x = load_img(path=path_to_data, target_size=(self.input_shape[0], self.input_shape[1])) 
        
        # Convert image to NumPy array
        x = img_to_array(img=x) 
        
        # Add an extra dimension at the beginning for batch
        x = np.expand_dims(a=x, axis=0) 
        
        # Preprocess the image according to the model's requirements
        x = preprocess_input(x=x)  
        
        return x

# %% [markdown]
# # Extraction of features from the dataset
#
# Extracting features from images using a provided model and saving them to a DataFrame.
#
# ## 1. Function Overview
# The `extract_feature_from_data` function extracts features from images using the provided model and saves them to a DataFrame. It takes an instance of the model class for feature extraction and the path to a CSV file containing file paths and class IDs.
#
# ## 2. Data Reading
# The function reads the data from the specified CSV file into a DataFrame.
#
# ## 3. Feature Extraction
# For each image in the DataFrame, the function preprocesses the image and extracts features using the provided model. It prints a message indicating the file being processed and calculates the elapsed time for feature extraction.
#
# ## 4. DataFrame Creation and Saving
# The extracted features, along with their corresponding class IDs, are collected into a DataFrame. The DataFrame is then saved as a CSV file for future use.
#
# This function facilitates efficient feature extraction from images using the provided model.

# %%
# Extract features from images
def extract_feature_from_data(input_model, path_to_data: str) -> float:
    """
    Extract features from images using the provided model and save them to a DataFrame.
    
    Args:
    :param input_model: An instance of the model class for feature extraction.
    :param path_to_data: The path to the CSV file containing file paths and class IDs.
    
    :return pd.elapsed_time: time taken to extract features.
    """
    # Read the data from the specified path into a DataFrame
    data_df = pd.read_csv(path_to_data)
    
    # Initialize an empty list to store features
    features = []
    
    # Initialize start time
    start_time = time.time()
    
    # Iterate over each row in the DataFrame
    for file_path, label in zip(data_df.file_path, data_df.id):
        # Print a message indicating which file is being processed
        print(f"\n> Extracting features from {os.path.basename(file_path)}")
        
        # Preprocess the image and extract features using the provided model
        preprocessed_image = input_model.loading_images(path_to_data=file_path)
        feature = input_model.model.predict(preprocessed_image)[0]
        normalize_feature = feature / np.linalg.norm(feature)
        
        # Append the extracted feature along with its corresponding class id to the features list
        features.append([normalize_feature, label])
    
    # Get the model name
    model_name = input_model.model_name
    
    # Calculate elapsed time
    elapsed_time = time.time() - start_time
    
    # Create a DataFrame to collect model name and elapsed time and save it as a csv file
    metadata_df = pd.DataFrame({"model_name": [model_name], "time_seconds": [elapsed_time], "time_minutes": [elapsed_time/60]})
    metadata_path = os.path.join(DATA_PATH, f"{model_name}_evaluation.csv")
    metadata_df.to_csv(path_or_buf=metadata_path, index=False, float_format="%.2f")
    
    # Create a DataFrame to collect all the extracted features
    features_df = pd.DataFrame(data=features, columns=["features", "id"], index=None)
    
    # Save features to JSON file
    json_path = os.path.join(DATA_PATH, f"{model_name}_extracted_feature.json")
    features_df.to_json(json_path, orient="records")
    
    return elapsed_time

# %%
# VGG16 model
vgg16_model = VGG16Model() # Create an instance of VGG16 class

# Check if the file exist
if not os.path.exists(path=VGG16_FEATURES_PATH):
    # Extracting features from dataset
    vgg16_extraction_time = extract_feature_from_data(input_model=vgg16_model, path_to_data=TRAIN_DATA_PATH)
    # Time to extract features
    print(f"\n> Extraction time: {vgg16_extraction_time:.2f} seconds - {vgg16_extraction_time/60:.2f} minutes") 
else:
    print(f"\n> Features already extracted and saved (location: {VGG16_FEATURES_PATH})")
# Out:
# > Extracting features from Non-Covid (460).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
#
# > Extracting features from Non-Covid (21).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (349).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (683).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (1125).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (111).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (814).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (765).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (716).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (641).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (432).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (760).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (104).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (549).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (505).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (690).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (193).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (792).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (563).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (623).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (409).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (462).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (265).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (231).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (980).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (153).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (801).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (376).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (350).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (600).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (813).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (129).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (411).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Covid (1000).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (974).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (258).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (816).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (450).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (531).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (148).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (491).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (1074).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (1216).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (918).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (1053).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (596).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (340).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (234).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (1003).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (1102).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (905).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (55).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (400).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (1116).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1133).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1220).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (326).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (442).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (282).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (275).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (729).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1194).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (1165).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (920).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (556).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (944).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (551).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (713).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
#
# > Extracting features from Non-Covid (1200).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (750).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Non-Covid (278).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
#
# > Extracting features from Covid (183).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#
# > Extracting features from Covid (994).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (229).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (724).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (796).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (979).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (945).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (536).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (905).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (268).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (328).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (504).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (697).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (178).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (793).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (309).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (478).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (308).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1147).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (417).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (161).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (113).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (671).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (708).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1120).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (470).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (997).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (798).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (46).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (287).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (401).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Covid (531).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (898).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (203).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (1077).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (87).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1041).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (41).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (995).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1146).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (696).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (395).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (384).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (467).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (665).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (972).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (17).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (846).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (171).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (185).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (209).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (1126).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1073).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (1216).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1163).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (557).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (569).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (112).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (216).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (1056).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (1061).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (319).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (97).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (1205).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (517).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (646).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (696).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (121).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (240).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (988).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (405).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (819).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Non-Covid (571).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1114).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (1121).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (302).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (967).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (901).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (1122).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (763).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (279).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1071).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (357).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (129).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (276).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (65).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (1076).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (522).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (892).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (1178).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (238).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (769).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (613).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (634).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (684).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (355).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (47).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (1088).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (480).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (311).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Covid (682).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (488).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (485).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (353).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (1190).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (534).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (205).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1219).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (803).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (909).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (1112).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (568).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (837).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (288).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (1167).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (222).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (88).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (82).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (538).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (1141).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
#
# > Extracting features from Non-Covid (519).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (680).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (271).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (614).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1145).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Covid (729).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (1045).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Covid (524).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (711).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (361).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (1171).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (535).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (1226).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (530).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (856).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (1140).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (333).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (770).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (369).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (124).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (40).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (191).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (281).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (751).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (1151).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (633).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (349).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Covid (647).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Covid (52).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (19).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Non-Covid (970).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (677).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
#
# > Extracting features from Non-Covid (621).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (373).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
#
# > Extracting features from Covid (1101).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Non-Covid (296).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (883).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (156).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
#
# > Extracting features from Non-Covid (204).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Non-Covid (1081).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (346).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (542).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
#
# > Extracting features from Non-Covid (853).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (342).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (1171).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (332).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (1158).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (745).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1205).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (589).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
#
# > Extracting features from Covid (139).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (189).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (965).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (387).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (775).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (337).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (166).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (41).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (1160).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (308).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (567).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (142).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (169).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (14).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (280).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (1180).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (1047).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (695).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (824).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Non-Covid (754).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
#
# > Extracting features from Covid (1092).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (221).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (971).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (676).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (430).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (593).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (907).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (160).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (638).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Non-Covid (889).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (312).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
#
# > Extracting features from Covid (987).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#
# > Extracting features from Covid (809).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#
# > Extracting features from Covid (255).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Covid (611).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#
# > Extracting features from Non-Covid (369).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (261).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
#
# > Extracting features from Non-Covid (389).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Non-Covid (396).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#
# > Extracting features from Non-Covid (867).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
#
# > Extracting features from Non-Covid (1214).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
#
# > Extracting features from Covid (613).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
#
# > Extracting features from Non-Covid (1119).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
#
# > Extracting features from Covid (241).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#
# > Extracting features from Covid (878).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (1113).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (1186).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (1192).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (280).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (631).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (1042).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (12).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Non-Covid (197).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
#
# > Extracting features from Covid (99).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (577).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (1004).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#
# > Extracting features from Covid (373).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (573).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (911).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (1026).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (234).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (721).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (1196).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (785).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (257).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (161).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (558).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (719).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (71).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (938).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (575).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
#
# > Extracting features from Covid (511).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (396).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (241).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (995).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (264).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (535).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (547).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (952).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Covid (759).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (1113).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (649).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (80).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (391).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (252).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (273).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (311).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (127).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1229).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (1229).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#
# > Extracting features from Covid (123).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Covid (19).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (900).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (1107).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (796).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (900).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (737).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
#
# > Extracting features from Covid (86).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# > Extracting features from Covid (1230).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
#
# > Extracting features from Non-Covid (1149).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#
# > Extracting features from Non-Covid (94).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#
# > Extracting features from Covid (238).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#
# > Extracting features from Covid (358).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#
# > Extracting features from Non-Covid (890).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
#
# > Extracting features from Non-Covid (954).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Non-Covid (1164).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (201).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (538).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1083).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (562).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (940).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#
# > Extracting features from Covid (620).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
#
# > Extracting features from Non-Covid (250).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
#
# > Extracting features from Covid (1086).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#
# > Extracting features from Non-Covid (324).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
#
# > Extracting features from Covid (1208).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
#
# > Extracting features from Covid (414).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#
# > Extracting features from Non-Covid (90).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#
# > Extracting features from Non-Covid (1152).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
#
# > Extracting features from Covid (436).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
#
# > Extracting features from Covid (525).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
#
# > Extracting features from Covid (416).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Non-Covid (771).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (1025).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1131).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (739).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (936).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (618).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (927).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (702).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (574).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (458).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (738).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (901).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (503).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Non-Covid (594).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (704).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (881).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (341).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
#
# > Extracting features from Covid (629).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Non-Covid (1156).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (103).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Covid (1119).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (888).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (49).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (102).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (941).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (70).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (850).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (1095).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (1248).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (190).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (406).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
#
# > Extracting features from Covid (1197).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
#
# > Extracting features from Covid (174).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#
# > Extracting features from Covid (1210).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#
# > Extracting features from Covid (607).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (996).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#
# > Extracting features from Covid (21).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (1008).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (786).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Non-Covid (26).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (961).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (1060).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Non-Covid (705).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (352).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (707).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (89).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (138).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (379).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (1147).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (595).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#
# > Extracting features from Covid (655).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Non-Covid (115).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (26).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (973).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#
# > Extracting features from Non-Covid (188).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Covid (956).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (668).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (508).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (1193).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Covid (1051).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (695).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (527).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (1131).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (931).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (363).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (380).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (618).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Covid (860).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#
# > Extracting features from Non-Covid (828).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#
# > Extracting features from Covid (1223).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (513).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Non-Covid (194).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (843).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (233).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (942).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Covid (725).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (186).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Covid (516).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
#
# > Extracting features from Covid (916).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
#
# > Extracting features from Non-Covid (1170).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (246).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Non-Covid (1137).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (1043).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (289).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (968).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (835).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (1175).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (1029).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (412).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (804).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (359).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (823).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (536).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (304).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (481).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (457).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (839).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Non-Covid (955).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (1095).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (113).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (888).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (944).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (588).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (752).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#
# > Extracting features from Covid (1179).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Covid (329).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (659).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (117).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (590).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (242).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# > Extracting features from Covid (715).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (893).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (586).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (467).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (870).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (257).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (560).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (219).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
#
# > Extracting features from Non-Covid (708).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (128).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (728).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (3).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (272).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (440).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (1130).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (318).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (519).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (940).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (918).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Non-Covid (1117).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (320).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (330).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (123).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (540).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (551).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (629).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (1013).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (42).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (720).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (115).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (998).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (564).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (1107).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (132).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (291).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (926).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (341).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (264).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Covid (1077).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (283).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (325).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (664).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (98).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (903).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Covid (784).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (886).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (956).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Non-Covid (198).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (1168).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (464).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (1068).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Covid (245).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (365).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (137).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (262).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (1075).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (31).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (494).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (367).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (602).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (394).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (1057).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (642).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (192).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Covid (563).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (722).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (45).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (692).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (403).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (368).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (468).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Covid (6).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1140).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
#
# > Extracting features from Non-Covid (709).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
#
# > Extracting features from Covid (1068).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (66).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (871).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
# > Extracting features from Non-Covid (964).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (595).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (687).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1251).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (4).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Covid (320).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
#
# > Extracting features from Non-Covid (406).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
#
# > Extracting features from Non-Covid (672).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
#
# > Extracting features from Non-Covid (485).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Covid (1199).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (627).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (364).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
#
# > Extracting features from Non-Covid (1142).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#
# > Extracting features from Covid (247).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#
# ...
#
# > Extracting features from Non-Covid (1213).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Covid (399).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (29).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Covid (250).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (1074).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (1011).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Covid (978).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Covid (919).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Non-Covid (281).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (1078).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Non-Covid (891).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Non-Covid (1058).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (518).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (435).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (707).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (924).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (1092).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#
# > Extracting features from Covid (209).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# > Extracting features from Non-Covid (677).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#
# > Extracting features from Non-Covid (916).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#
# > Extracting features from Non-Covid (1180).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Non-Covid (509).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Non-Covid (469).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (1151).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (557).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (1132).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
#
# > Extracting features from Non-Covid (866).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (933).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (119).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Covid (423).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Non-Covid (1002).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Covid (702).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (304).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (1048).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (361).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Covid (954).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Covid (296).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Covid (353).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Non-Covid (507).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (576).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (958).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Non-Covid (923).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Non-Covid (69).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Covid (700).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#
# > Extracting features from Covid (776).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Non-Covid (215).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Covid (268).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#
# > Extracting features from Non-Covid (839).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (1051).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (1016).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (101).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Covid (433).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
#
# > Extracting features from Covid (685).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (803).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (743).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Covid (842).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Non-Covid (314).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Covid (93).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (203).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Covid (313).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Non-Covid (524).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (407).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Covid (274).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Non-Covid (13).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (1150).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (836).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Covid (1249).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (882).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
#
# > Extracting features from Covid (1038).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#
# > Extracting features from Covid (1025).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
#
# > Extracting features from Covid (237).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
#
# > Extracting features from Covid (417).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Non-Covid (981).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (331).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Non-Covid (459).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# > Extracting features from Non-Covid (941).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#
# > Extracting features from Non-Covid (855).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Non-Covid (747).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Non-Covid (686).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (179).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (673).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# > Extracting features from Covid (89).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
#
# > Extracting features from Non-Covid (210).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# > Extracting features from Non-Covid (1078).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#
# > Extracting features from Non-Covid (1083).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
#
# > Extracting features from Non-Covid (483).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#
# > Extracting features from Non-Covid (978).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Non-Covid (652).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Covid (779).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Covid (820).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Covid (298).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#
# > Extracting features from Non-Covid (533).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Covid (721).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Non-Covid (872).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#
# > Extracting features from Non-Covid (81).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (512).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Non-Covid (426).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (897).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (1094).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (1003).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (500).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (1191).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Non-Covid (272).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (79).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (977).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (539).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (807).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Non-Covid (233).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Covid (569).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (566).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (920).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (176).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (324).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Non-Covid (273).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (1227).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (1213).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (152).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Non-Covid (416).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (636).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#
# > Extracting features from Covid (554).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# > Extracting features from Non-Covid (345).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#
# > Extracting features from Non-Covid (529).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
#
# > Extracting features from Covid (898).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (619).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (461).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (514).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# > Extracting features from Non-Covid (910).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# > Extracting features from Covid (15).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (453).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (853).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (989).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Non-Covid (806).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (302).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1158).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (582).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (270).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (854).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (83).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#
# > Extracting features from Covid (858).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (689).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (360).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (765).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Covid (422).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (392).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#
# > Extracting features from Covid (544).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Covid (1072).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Covid (581).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Covid (102).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Non-Covid (549).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Non-Covid (817).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (802).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (248).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (1118).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (971).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (34).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (182).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Non-Covid (322).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Covid (200).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#
# > Extracting features from Covid (817).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Covid (432).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (868).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (295).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Covid (1089).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Non-Covid (691).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (671).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (832).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# > Extracting features from Covid (1204).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# > Extracting features from Non-Covid (370).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# > Extracting features from Non-Covid (976).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
#
# > Extracting features from Covid (660).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
#
# > Extracting features from Covid (1065).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# > Extracting features from Covid (838).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
#
# > Extracting features from Non-Covid (690).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Non-Covid (300).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# > Extracting features from Covid (360).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (777).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#
# > Extracting features from Non-Covid (717).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (510).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Non-Covid (786).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Covid (930).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# > Extracting features from Covid (216).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#
# > Extracting features from Covid (5).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extracting features from Non-Covid (466).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Non-Covid (986).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# > Extracting features from Covid (424).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# > Extracting features from Covid (548).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#
# > Extracting features from Covid (1088).png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#
# > Extraction time: 370.49 seconds - 6.17 minutes

# %% [markdown]
# # Image Similarity Analysis
#
# This Markdown cell summarizes code for comparing features of images based on a chosen distance metric and finding similar images.
#
# ## 1. Finding Similar Images
# The `find_similar_images` function compares features of a query image with features of all images in the dataset based on a given distance metric. It returns the indices of the most similar images and their corresponding distances.
#
# ## 2. Plotting Similar Images
# The `plot_similar_images` function plots the query image along with similar images, their distances, and associated classes. It organizes the images in a grid structure with 5 images per row and saves the plot as an image file.
#
# ## 3. Choosing Query Image and Distance Metric
# The `choose_query_file_and_distance` function displays available files from the test dataset and prompts the user to choose one. It also prompts the user to choose a distance metric ("Cosine", "Euclidean", or "Manhattan") for comparison.
#
# This code facilitates the comparison and visualization of similar images based on user-defined distance metrics.

# %%
# Compare features based on distance metric and find similarity
def find_similar_images(features_of_query: np.array, all_features: np.array, distance_metric: str, top_n=15) -> tuple[int, int, str]:
    """
    Find similar images to the query image based on a given distance metric function.
 
    :param features_of_query: Features of the query image.
    :param all_features: Features of all images in the dataset.
    :param distance_metric: Metric to use for distance calculation. 
    Options: "Cosine", "Euclidean" or "Manhattan".
    :param top_n: Number of top similar images to consider. Default is 15.

    :return: Indices of the most similar images and their corresponding distances.
    """
    # Choose distance metric function
    if distance_metric == COSINE:
        distance_func = cosine_distances
    elif distance_metric == EUCLIDEAN:
        distance_func = euclidean_distances
    elif distance_metric == MANHATTAN:
        distance_func = manhattan_distances
    else:
        raise ValueError("Invalid distance metric. Please choose 'Cosine', 'Euclidean', 'Manhattan'.")
    
    # Reshape or flatten the query features
    if len(features_of_query.shape) > 2:
        features_of_query = features_of_query.flatten()

    # Reshape or flatten all features
    if len(all_features.shape) > 2:
        all_features = all_features.reshape(all_features.shape[0], -1)
    
    # Calculate distances between the query image features and all other images
    distances = distance_func(X=features_of_query.reshape(1, -1), Y=all_features)
    
    # Sort distances and get the indices of the closest images
    closest_indices = distances.argsort()[0][:top_n]
    closest_distances = distances[0][closest_indices]
    
    return closest_indices, closest_distances, distance_metric


# Plot similar images based on chosen distance method
def plot_similar_images(path_to_query_image: str, query_class_label: int, similar_image_paths: np.array(str), 
                        similar_class_labels: np.array(int), similar_distance_parameters:list[int], distance_metric: str) -> None:
    """
    Plot the query image along with similar images, their distances, and associated classes.

    :param path_to_query_image: File path of the query image.
    :param query_class_label: Class label of the query image.
    :param similar_image_paths: List of file paths of predicted similar images.
    :param similar_class_labels: List of predicted class labels corresponding to similar images.
    :param similar_distance_parameters: List of distance values corresponding to similar images.
    :param distance_metric: Name of the distance metric adopted.
    """
    num_similar_images = len(similar_image_paths)
    num_rows = int(np.ceil(num_similar_images / 5))  # Organize in a grid structure with 5 images per row

    # Load and display the query image separately
    plt.figure(figsize=(20, (num_rows + 1) * 4))
    
    # Add legend for distance metric and its range
    plt.subplot(num_rows + 1, 5, 1)
    plt.axis("off")
    range_text = DISTANCE_RANGES.get(distance_metric)
    if range_text is None:
        range_text = "Not specified"
    plt.text(0, 0.5, f"Legend:\n - distance: {distance_metric}\n - range: {range_text}", fontsize=16, ha="left", weight="bold", bbox=dict(facecolor="white", alpha=0.5))
    
    # Centered position for the query image
    plt.subplot(num_rows + 1, 5, 3) 
    plt.imshow(mpimg.imread(path_to_query_image))
    if query_class_label == 0:
        plt.title(f"Query Image:{os.path.basename(path_to_query_image)}\nClass: COVID", fontsize=14, weight="bold", bbox=dict(facecolor="lightgrey", alpha=0.5))
    else:
        plt.title(f"Query Image:{os.path.basename(path_to_query_image)}\nClass: NON COVID", fontsize=14, weight="bold", bbox=dict(facecolor="lightgrey", alpha=0.5))
    plt.axis("off")

    # Plot similar images and their distances in a grid
    for figure_number, (path, similar_class, distance_parameter) in enumerate(zip(similar_image_paths, similar_class_labels, similar_distance_parameters), 1):
        plt.subplot(num_rows + 1, 5, figure_number + 5)  # Start plotting from the 2nd row
        plt.imshow(mpimg.imread(path))
        
        if similar_class == query_class_label:
            title_color = "green"
        else:
            title_color = "red"
        
        if similar_class == 0:
            plt.title(f"Image:{os.path.basename(path)}\nClass: COVID\n{distance_metric} Distance: {distance_parameter:.3f}", 
                      color=title_color, fontsize=14, weight="bold", bbox=dict(facecolor="lightgrey", alpha=0.5))
        else:
            plt.title(f"Image:{os.path.basename(path)}\nClass: NON COVID\n{distance_metric} Distance: {distance_parameter:.3f}", 
                      color=title_color, fontsize=14, weight="bold", bbox=dict(facecolor="lightgrey", alpha=0.5))
        plt.axis("off")
        
    plt.tight_layout()
    
    # Save the plot to path
    plot_path = os.path.join(PLOT_PATH, f"{os.path.basename(path_to_query_image).split(".")[0]}_{distance_metric}.png") 
    plt.savefig(plot_path, dpi=96)
    
    # Display plot
    plt.show()
    

# Choose which of the images to analyze and how
def choose_query_file_and_distance(query_dataset: pd.DataFrame, select_distance: bool) -> tuple[str, int, str]:
    """
    Prompts the user to choose an image file from a dataset along with a distance function.
    
    :param query_dataset: DataFrame containing image file paths and labels.
    :param select_distance: If True, prompts for selecting both an image file and a distance function. 
            If False, only prompts for selecting an image file.

    :returns: 'query_file_path': query file path. 
             'query_id': query corresponding class label.
             'distance_func': chosen distance function by the user.
    """
    query_file_path = str
    query_id = id
    distance_func = str
    
    # Construct the prompt message for file selection
    file_names = [os.path.basename(path) for path in query_dataset["file_path"]]
    file_prompt_message = (f"Enter the index of the file you want to choose.\n"
                           f"Options:\n\n[index - file]\n")
    for i, file_name in enumerate(file_names):
        file_prompt_message += f"{i}\t-\t{file_name}\n"
    
    while True:
        file_choice = input(file_prompt_message)
        if file_choice.strip() == "":
            print("No input provided. Please enter a valid index!")
            continue
        
        try:
            file_choice = int(file_choice)
            if file_choice < 0 or file_choice >= len(query_dataset):
                print("Invalid index. Please choose a valid index!")
                continue
            else:
                query_file_path = query_dataset.iloc[file_choice]["file_path"]
                query_id = query_dataset.iloc[file_choice]["id"]
                break
        except ValueError:
            print("Invalid input. Please enter a valid index!")
    
    # If select_distance is True, prompt for distance function selection
    if select_distance:
        # Construct the prompt message for distance function selection
        distance_prompt_message = ("Choose the distance function:\n"
                                   "1 - Cosine\n"
                                   "2 - Euclidean\n"
                                   "3 - Manhattan\n")

        while True:
            distance_choice = input(distance_prompt_message)
            if distance_choice not in {"1", "2", "3"}:
                print("Invalid choice. Please enter a valid number!")
                continue
            else:
                if distance_choice == "1":
                    distance_func = "Cosine"
                elif distance_choice == "2":
                    distance_func = "Euclidean"
                elif distance_choice == "3":
                    distance_func = "Manhattan"
                break
    
    return query_file_path, query_id, distance_func

# %%
## ************************************ VGG16 - FROM QUERY FIND SIMILAR ********************************** ##

# Load the features from the correct JSON file
vgg16_features_dataframe = pd.read_json(path_or_buf=VGG16_FEATURES_PATH)

# Read the data from the specified path 
train_data = pd.read_csv(filepath_or_buffer=TRAIN_DATA_PATH)
test_data = pd.read_csv(filepath_or_buffer=TEST_DATA_PATH)

# Choose a file from the test dataset
chosen_file_path, chosen_id, distance = choose_query_file_and_distance(query_dataset=test_data, select_distance=True)

# Load the query image and extract feature from it
vgg16_query_features = vgg16_model.loading_images(path_to_data=chosen_file_path)
vgg16_query_features = vgg16_model.model.predict(x=vgg16_query_features)[0]
vgg16_query_features = vgg16_query_features / np.linalg.norm(x=vgg16_query_features)

# VGG16 extracted features
vgg16_all_features = np.array(vgg16_features_dataframe["features"].to_list())

# Calculate cosine distances and find similar images
similar_indices, similar_distances, distance_function = find_similar_images(features_of_query=vgg16_query_features, 
                                                                            all_features=vgg16_all_features,
                                                                            distance_metric=distance)

# Print info. about query
print(f"\n> Query image: {chosen_file_path}"
      f"\n> Query label: {chosen_id}")

# Lists of similar image found and corresponding true labels
similar_images = [train_data.iloc[index]["file_path"] for index in similar_indices]
similar_labels = np.array([train_data.iloc[index]["id"] for index in similar_indices])

# Given query -> Plot similar images with class labels and info.
plot_similar_images(path_to_query_image=chosen_file_path, 
                    query_class_label=chosen_id, 
                    similar_image_paths=similar_images,
                    similar_class_labels=similar_labels, 
                    similar_distance_parameters=similar_distances,
                    distance_metric=distance_function)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
#
# > Query image: archives/COVID/Covid (229).png
# > Query label: 0

# %% [markdown]
# # Evaluation of the model performance
#
# It computes precision, recall, and F1-score for each distance metric and prints the evaluation metrics.

# %%
# Precision score
def precision_score(query_label: int, y_true: np.array, y_pred: np.array) -> float:
    """
    Compute precision score.

    :param query_label: Chosen image ID.
    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.

    :return: Precision score.
    """
    true_positives = int
    false_positives = int

    if query_label == 0:  # COVID
        true_positives = np.sum((y_true == 0) & (y_pred == 0))
        false_positives = np.sum((y_true == 1) & (y_pred == 0))
    elif query_label == 1:  # non-COVID
        true_positives = np.sum((y_true == 1) & (y_pred == 1))
        false_positives = np.sum((y_true == 0) & (y_pred == 1))

    if true_positives + false_positives == 0:
        return 0.0

    precision = true_positives / (true_positives + false_positives)
    
    return precision


# Recall score
def recall_score(query_label: int, y_true: np.array, y_pred: np.array) -> float:
    """
    Compute recall score.

    :param query_label: Chosen image ID.
    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.

    :return: Recall score.
    """
    true_positives = int
    false_negatives = int

    if query_label == 0:  # COVID
        true_positives = np.sum((y_true == 0) & (y_pred == 0))
        false_negatives = np.sum((y_true == 0) & (y_pred == 1))
    elif query_label == 1:  # non-COVID
        true_positives = np.sum((y_true == 1) & (y_pred == 1))
        false_negatives = np.sum((y_true == 1) & (y_pred == 0))

    if true_positives + false_negatives == 0:
        return 0.0

    recall = true_positives / (true_positives + false_negatives)
    
    return recall


# F1-score 
def f1_score(computed_precision: float, computed_recall: float) -> float:
    """
    Compute F1-score.

    :param computed_precision: computed precision score.
    :param computed_recall: computed recall score.

    :return: F1-score.
    """
    if computed_precision + computed_recall == 0:
        return 0.0

    f1 = 2 * (computed_precision * computed_recall) / (computed_precision + computed_recall)
    
    return f1

# %%
# Evaluation of the model performance
def evaluate_similarity(query_img_features: np.array, query_img_id: int, all_features: np.array, top_n=100) -> tuple[float, float, float]:
    """
    Evaluate the similarity between the query image and all other images in the dataset.

    :param query_img_features: Features of the query image.
    :param query_img_id: ID of the query image.
    :param all_features: Features of all images in the dataset.
    :param top_n: Number of top similar images to consider for top-N accuracy.

    :return: precision, recall, F1-score.
    """
    # Reshape or flatten the query features
    if len(query_img_features.shape) > 2:
        query_img_features = query_img_features.flatten()
    
    # Reshape or flatten all features
    if len(all_features.shape) > 2:
        all_features = all_features.reshape(all_features.shape[0], -1)
    
    for distance_metric in [COSINE, EUCLIDEAN, MANHATTAN]:
        # Calculate distances between the query image features and all other images
        if distance_metric == COSINE:
            distances = cosine_distances(query_img_features.reshape(1, -1), all_features)
        elif distance_metric == EUCLIDEAN:
            distances = euclidean_distances(query_img_features.reshape(1, -1), all_features)
        elif distance_metric == MANHATTAN:
            distances = manhattan_distances(query_img_features.reshape(1, -1), all_features)
        else:
            raise ValueError("Invalid distance metric. Choose from 'Cosine', 'Euclidean', 'Manhattan'.")

        # Sort distances and get the indices of the closest top_n images
        closest_indices = distances.argsort()[0][:top_n]

        # Extract labels for the top similar images
        retrieved_labels = np.array([train_data.iloc[index]["id"] for index in closest_indices])
        
        # Predictions -> the top_n retrieved elements are considered belonging to the query class label
        predicted_labels = np.array([query_img_id] * len(retrieved_labels))
        
        # Compute metrics
        precision = precision_score(query_label=query_img_id, y_true=retrieved_labels, y_pred=predicted_labels)
        recall = recall_score(query_label=query_img_id, y_true=retrieved_labels, y_pred=predicted_labels)
        f1 = f1_score(computed_precision=precision, computed_recall=recall)
        
        return precision, recall, f1

# %%
## ************************************ VGG16 - COMPUTE THE EVALUATION METRICS ********************************** ##

# Choose a file from the test dataset
chosen_file_path, chosen_id, _ = choose_query_file_and_distance(query_dataset=test_data, select_distance=False)

# Print information about the chosen file
print(f"> Chosen image: {chosen_file_path}")
print(f"> Chosen ID: {chosen_id}")

# Load the query image
query = vgg16_model.loading_images(path_to_data=chosen_file_path)
query = vgg16_model.model.predict(x=query)[0]
query = query / np.linalg.norm(x=query)

# Evaluate the performance of the model
precision_score_value, recall_score_value, f1_score_value = evaluate_similarity(query_img_features=query, 
                                                                                query_img_id=chosen_id, 
                                                                                all_features=vgg16_all_features, 
                                                                                top_n=100)
# Print Evaluation scores
print(f"\n> Evaluation score:")
print(f"-- Precision score: {precision_score_value:.3f}")
print(f"-- Recall score: {recall_score_value:.3f}")
print(f"-- F1-score: {f1_score_value:.3f}")
# Out:
# > Chosen image: archives/COVID/Covid (229).png
# > Chosen ID: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
#
# > Evaluation score:
# -- Precision score: 0.940
# -- Recall score: 1.000
# -- F1-score: 0.969

# %% [markdown]
# # Models Evaluation

# %%
# Evaluation of the model performances
def model_evaluation(input_model, test_dataset: pd.DataFrame, model_extracted_features: np.ndarray):
    
    all_precision = []
    all_recall = []
    all_f1 = []
    
    # Loop through the test dataset
    for query_path, query_id in zip(test_dataset["file_path"], test_dataset["id"]):
         
        # Load the query image and extract features
        query_features = input_model.loading_images(path_to_data=query_path)
        query_features = input_model.model.predict(x=query_features)[0]
        query_features = query_features / np.linalg.norm(x=query_features)
        
        # Compute evaluation metrics: precision, recall and f1-score
        model_precision, model_recall, model_f1 = evaluate_similarity(query_img_features=query_features, 
                                                                      query_img_id=query_id, 
                                                                      all_features=model_extracted_features, 
                                                                      top_n=100)
        # Append values
        all_precision.append(model_precision)
        all_recall.append(model_recall)
        all_f1.append(model_f1)
        
    mean_precision = np.mean(all_precision, axis=0)
    mean_recall = np.mean(all_recall, axis=0)
    mean_f1 = np.mean(all_f1, axis=0)
    
    # Load CSV file
    evaluation_file_path = os.path.join(DATA_PATH, f"{input_model.model_name}_evaluation.csv")
    evaluation_df = pd.read_csv(filepath_or_buffer=evaluation_file_path)
    
    # Add new columns to the existing DataFrame
    evaluation_df["mean_precision"] = mean_precision
    evaluation_df["mean_recall"] = mean_recall
    evaluation_df["mean_f1"] = mean_f1
    
    # Save the updated DataFrame back to CSV
    evaluation_df.to_csv(evaluation_file_path, index=False, float_format="%.3f")
    
    return mean_precision, mean_recall, mean_f1
    
    
## ************************************ COMPUTE THE EVALUATION METRICS ********************************** ##

# Vgg16 Evaluation
vgg16_average_precision, vgg16_average_recall, vgg16_average_f1  = model_evaluation(input_model=vgg16_model,  test_dataset=test_data, 
                                                                                    model_extracted_features=vgg16_all_features)

# Print Evaluation scores
print(f"\n> VGG16 Average evaluation:")
print(f"-- Precision: {vgg16_average_precision:.3f}")
print(f"-- Recall: {vgg16_average_recall:.3f}")
print(f"-- F1-score: {vgg16_average_f1:.3f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
#
# > VGG16 Average evaluation:
# -- Precision: 0.738
# -- Recall: 1.000
# -- F1-score: 0.833
